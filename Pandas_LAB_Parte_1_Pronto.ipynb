# %% [markdown]
# <img src="https://github.com/danielscarvalho/data/blob/master/img/FIAP-logo.png?raw=True" style="float:right;" width="200px">
#
# # DATA SCIENCE & STATISTICAL COMPUTING [》](https://www.fiap.com.br/)
#
# ## Dataframe & Python
#
# ### LAP Parte 1: “10 minutes to pandas"
#
# https://pandas.pydata.org/docs/user_guide/10min.html

# %% [markdown]
# Sugestão: Colocar a página do Cookbook lado a lado com este notebook para realizar as operações.

# %%
import numpy as np

# %%
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  2.097275 -0.432949 -0.805111  0.462605
# 2013-01-02 -1.500338  1.212460 -0.108714  0.562117
# 2013-01-03 -0.135610 -0.390578 -1.247080  1.577647
# 2013-01-04  0.851161 -1.328108  0.012595 -0.451990
# 2013-01-05  0.703999 -0.871839 -0.429878  0.213658
# 2013-01-06  0.173594 -0.429250  0.438432  1.781243

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  2.097275 -0.432949 -0.805111  0.462605
# 2013-01-02 -1.500338  1.212460 -0.108714  0.562117
# 2013-01-03 -0.135610 -0.390578 -1.247080  1.577647
# 2013-01-04  0.851161 -1.328108  0.012595 -0.451990
# 2013-01-05  0.703999 -0.871839 -0.429878  0.213658

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.851161 -1.328108  0.012595 -0.451990
# 2013-01-05  0.703999 -0.871839 -0.429878  0.213658
# 2013-01-06  0.173594 -0.429250  0.438432  1.781243

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 2.09727492, -0.4329487 , -0.80511145,  0.46260466],
#        [-1.50033833,  1.21246007, -0.10871417,  0.56211705],
#        [-0.13561035, -0.39057763, -1.2470796 ,  1.57764655],
#        [ 0.85116058, -1.32810791,  0.01259545, -0.45199045],
#        [ 0.70399856, -0.87183904, -0.4298776 ,  0.21365759],
#        [ 0.17359447, -0.42925009,  0.43843212,  1.78124321]])

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.365013 -0.373377 -0.356626  0.690880
# std    1.193213  0.858117  0.604866  0.845911
# min   -1.500338 -1.328108 -1.247080 -0.451990
# 25%   -0.058309 -0.762116 -0.711303  0.275894
# 50%    0.438797 -0.431099 -0.269296  0.512361
# 75%    0.814370 -0.400246 -0.017732  1.323764
# max    2.097275  1.212460  0.438432  1.781243

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    2.097275   -1.500338   -0.135610    0.851161    0.703999    0.173594
# B   -0.432949    1.212460   -0.390578   -1.328108   -0.871839   -0.429250
# C   -0.805111   -0.108714   -1.247080    0.012595   -0.429878    0.438432
# D    0.462605    0.562117    1.577647   -0.451990    0.213658    1.781243

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.462605 -0.805111 -0.432949  2.097275
# 2013-01-02  0.562117 -0.108714  1.212460 -1.500338
# 2013-01-03  1.577647 -1.247080 -0.390578 -0.135610
# 2013-01-04 -0.451990  0.012595 -1.328108  0.851161
# 2013-01-05  0.213658 -0.429878 -0.871839  0.703999
# 2013-01-06  1.781243  0.438432 -0.429250  0.173594

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-04  0.851161 -1.328108  0.012595 -0.451990
# 2013-01-05  0.703999 -0.871839 -0.429878  0.213658
# 2013-01-01  2.097275 -0.432949 -0.805111  0.462605
# 2013-01-06  0.173594 -0.429250  0.438432  1.781243
# 2013-01-03 -0.135610 -0.390578 -1.247080  1.577647
# 2013-01-02 -1.500338  1.212460 -0.108714  0.562117

# %%
df["A"]
# Out:
# 2013-01-01    2.097275
# 2013-01-02   -1.500338
# 2013-01-03   -0.135610
# 2013-01-04    0.851161
# 2013-01-05    0.703999
# 2013-01-06    0.173594
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  2.097275 -0.432949 -0.805111  0.462605
# 2013-01-02 -1.500338  1.212460 -0.108714  0.562117
# 2013-01-03 -0.135610 -0.390578 -1.247080  1.577647

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.500338  1.212460 -0.108714  0.562117
# 2013-01-03 -0.135610 -0.390578 -1.247080  1.577647
# 2013-01-04  0.851161 -1.328108  0.012595 -0.451990

# %%
df.loc[dates[0]]
# Out:
# A    2.097275
# B   -0.432949
# C   -0.805111
# D    0.462605
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  2.097275 -0.432949
# 2013-01-02 -1.500338  1.212460
# 2013-01-03 -0.135610 -0.390578
# 2013-01-04  0.851161 -1.328108
# 2013-01-05  0.703999 -0.871839
# 2013-01-06  0.173594 -0.429250

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -1.500338  1.212460
# 2013-01-03 -0.135610 -0.390578
# 2013-01-04  0.851161 -1.328108

# %%
df.loc[dates[0], "A"]
# Out:
# 2.097274920482487

# %%
df.at[dates[0], "A"]
# Out:
# 2.097274920482487

# %%
df.iloc[3]
# Out:
# A    0.851161
# B   -1.328108
# C    0.012595
# D   -0.451990
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.851161 -1.328108
# 2013-01-05  0.703999 -0.871839

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02 -1.500338 -0.108714
# 2013-01-03 -0.135610 -1.247080
# 2013-01-05  0.703999 -0.429878

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.500338  1.212460 -0.108714  0.562117
# 2013-01-03 -0.135610 -0.390578 -1.247080  1.577647

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -0.432949 -0.805111
# 2013-01-02  1.212460 -0.108714
# 2013-01-03 -0.390578 -1.247080
# 2013-01-04 -1.328108  0.012595
# 2013-01-05 -0.871839 -0.429878
# 2013-01-06 -0.429250  0.438432

# %%
df.iloc[1, 1]
# Out:
# 1.2124600738653883

# %%
df.iat[1, 1]
# Out:
# 1.2124600738653883

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  2.097275 -0.432949 -0.805111  0.462605
# 2013-01-04  0.851161 -1.328108  0.012595 -0.451990
# 2013-01-05  0.703999 -0.871839 -0.429878  0.213658
# 2013-01-06  0.173594 -0.429250  0.438432  1.781243

# %%
df[df > 0]
# Out:
#                    A        B         C         D
# 2013-01-01  2.097275      NaN       NaN  0.462605
# 2013-01-02       NaN  1.21246       NaN  0.562117
# 2013-01-03       NaN      NaN       NaN  1.577647
# 2013-01-04  0.851161      NaN  0.012595       NaN
# 2013-01-05  0.703999      NaN       NaN  0.213658
# 2013-01-06  0.173594      NaN  0.438432  1.781243

# %%
df2 = df.copy()

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three"]

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  2.097275 -0.432949 -0.805111  0.462605    one
# 2013-01-02 -1.500338  1.212460 -0.108714  0.562117    one
# 2013-01-03 -0.135610 -0.390578 -1.247080  1.577647    two
# 2013-01-04  0.851161 -1.328108  0.012595 -0.451990  three
# 2013-01-05  0.703999 -0.871839 -0.429878  0.213658   four
# 2013-01-06  0.173594 -0.429250  0.438432  1.781243  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.135610 -0.390578 -1.247080  1.577647   two
# 2013-01-05  0.703999 -0.871839 -0.429878  0.213658  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.805111  5.0  NaN
# 2013-01-02 -1.500338  1.212460 -0.108714  5.0  1.0
# 2013-01-03 -0.135610 -0.390578 -1.247080  5.0  2.0
# 2013-01-04  0.851161 -1.328108  0.012595  5.0  3.0
# 2013-01-05  0.703999 -0.871839 -0.429878  5.0  4.0
# 2013-01-06  0.173594 -0.429250  0.438432  5.0  5.0

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.805111 -5.0  NaN
# 2013-01-02 -1.500338 -1.212460 -0.108714 -5.0 -1.0
# 2013-01-03 -0.135610 -0.390578 -1.247080 -5.0 -2.0
# 2013-01-04 -0.851161 -1.328108 -0.012595 -5.0 -3.0
# 2013-01-05 -0.703999 -0.871839 -0.429878 -5.0 -4.0
# 2013-01-06 -0.173594 -0.429250 -0.438432 -5.0 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

# %%
df1.loc[dates[0] : dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.805111  5.0  NaN  1.0
# 2013-01-02 -1.500338  1.212460 -0.108714  5.0  1.0  1.0
# 2013-01-03 -0.135610 -0.390578 -1.247080  5.0  2.0  NaN
# 2013-01-04  0.851161 -1.328108  0.012595  5.0  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A        B         C    D    F    E
# 2013-01-02 -1.500338  1.21246 -0.108714  5.0  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.805111  5.0  5.0  1.0
# 2013-01-02 -1.500338  1.212460 -0.108714  5.0  1.0  1.0
# 2013-01-03 -0.135610 -0.390578 -1.247080  5.0  2.0  5.0
# 2013-01-04  0.851161 -1.328108  0.012595  5.0  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.015467
# B   -0.301219
# C   -0.356626
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.048722
# 2013-01-02    1.120682
# 2013-01-03    1.045346
# 2013-01-04    1.507130
# 2013-01-05    1.680456
# 2013-01-06    2.036555
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.135610 -1.390578 -2.247080  4.0  1.0
# 2013-01-04 -2.148839 -4.328108 -2.987405  2.0  0.0
# 2013-01-05 -4.296001 -5.871839 -5.429878  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A     0.086618
# B    -1.686827
# C    -1.997105
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000  -81.477279  506.0    NaN
# 2013-01-02 -151.834239  122.700959  -11.001874  506.0  101.2
# 2013-01-03  -13.723768  -39.526456 -126.204456  506.0  202.4
# 2013-01-04   86.137451 -134.404520    1.274660  506.0  303.6
# 2013-01-05   71.244654  -88.230110  -43.503613  506.0  404.8
# 2013-01-06   17.567761  -43.440109   44.369331  506.0  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# 4    2
# 5    4
# 6    2
# 7    2
# 8    3
# 9    1
# dtype: int64

# %%
s.value_counts()
# Out:
# 2    5
# 1    2
# 3    2
# 4    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.225872 -0.636774  0.690526 -0.178066
# 1 -2.242152 -0.941883 -1.254864  0.543887
# 2  0.778704 -0.535640  0.161702 -0.457127
# 3  0.705375 -0.742808  0.996713  0.191018
# 4 -0.598487 -0.608993 -0.053121  0.662819
# 5 -0.871661  0.470214  0.795030 -1.307383
# 6 -0.210507  0.726016  0.338400 -1.701753
# 7  0.319247 -0.282448 -0.363561 -0.495731
# 8  0.008808  0.714155 -0.765327  0.424081
# 9  1.076569 -1.281305  0.314784 -0.727607

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.225872 -0.636774  0.690526 -0.178066
# 1 -2.242152 -0.941883 -1.254864  0.543887
# 2  0.778704 -0.535640  0.161702 -0.457127
# 3  0.705375 -0.742808  0.996713  0.191018
# 4 -0.598487 -0.608993 -0.053121  0.662819
# 5 -0.871661  0.470214  0.795030 -1.307383
# 6 -0.210507  0.726016  0.338400 -1.701753
# 7  0.319247 -0.282448 -0.363561 -0.495731
# 8  0.008808  0.714155 -0.765327  0.424081
# 9  1.076569 -1.281305  0.314784 -0.727607

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.553340 -0.154024
# 1  bar    one  1.542039 -0.541676
# 2  foo    two  0.743420  0.063517
# 3  bar  three -0.860544  0.269309
# 4  foo    two  0.000825  0.277247
# 5  bar    two -1.907593  0.455480
# 6  foo    one -0.713076 -0.316758
# 7  foo  three  0.604762 -0.136382

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -1.226097  0.183113
# foo  1.189270 -0.266400

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    1.542039 -0.541676
#     three -0.860544  0.269309
#     two   -1.907593  0.455480
# foo one   -0.159736 -0.470782
#     three  0.604762 -0.136382
#     two    0.744244  0.340765

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.150127  0.978511
#       two     0.383847 -0.564015
# baz   one    -1.454023 -0.380345
#       two     0.386180  0.169665

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -0.150127
#                B    0.978511
#        two     A    0.383847
#                B   -0.564015
# baz    one     A   -1.454023
#                B   -0.380345
#        two     A    0.386180
#                B    0.169665
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.150127  0.978511
#       two     0.383847 -0.564015
# baz   one    -1.454023 -0.380345
#       two     0.386180  0.169665

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.150127  0.383847
#       B  0.978511 -0.564015
# baz   A -1.454023  0.386180
#       B -0.380345  0.169665

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.150127 -1.454023
#        B  0.978511 -0.380345
# two    A  0.383847  0.386180
#        B -0.564015  0.169665

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.793128  0.107255
# 1     one  B  foo  0.122054 -0.809210
# 2     two  C  foo  0.302470 -0.735491
# 3   three  A  bar  0.434655  0.198226
# 4     one  B  bar -0.429050  0.229714
# 5     one  C  bar  0.407831  0.375080
# 6     two  A  foo -1.543624  0.985661
# 7   three  B  foo -0.687969  0.460045
# 8     one  C  foo -1.245209  0.463281
# 9     one  A  bar  0.013178  0.659771
# 10    two  B  bar  0.393838  0.217078
# 11  three  C  bar -0.118876 -0.342041

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.013178  0.793128
#       B -0.429050  0.122054
#       C  0.407831 -1.245209
# three A  0.434655       NaN
#       B       NaN -0.687969
#       C -0.118876       NaN
# two   A       NaN -1.543624
#       B  0.393838       NaN
#       C       NaN  0.302470

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    27112
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -2.021781
# 2012-03-07   -0.433227
# 2012-03-08    2.269272
# 2012-03-09    0.974968
# 2012-03-10    0.788277
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -2.021781
# 2012-03-07 00:00:00+00:00   -0.433227
# 2012-03-08 00:00:00+00:00    2.269272
# 2012-03-09 00:00:00+00:00    0.974968
# 2012-03-10 00:00:00+00:00    0.788277
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -2.021781
# 2012-03-06 19:00:00-05:00   -0.433227
# 2012-03-07 19:00:00-05:00    2.269272
# 2012-03-08 19:00:00-05:00    0.974968
# 2012-03-09 19:00:00-05:00    0.788277
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

df = df.cumsum()
plt.figure();
df.plot();
plt.legend(loc="best");

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

# %%
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  4  0  0  2  1
# 1           1  1  1  4  3  3
# 2           2  1  0  1  2  3
# 3           3  0  2  4  4  0
# 4           4  1  1  0  4  0
# 5           5  3  3  0  1  0
# 6           6  3  1  4  2  2
# 7           7  1  3  3  0  2
# 8           8  3  4  0  1  1
# 9           9  2  4  4  3  0

# %%
df.to_parquet("foo.parquet")

# %%
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  4  0  0  2  1
# 1  1  1  4  3  3
# 2  1  0  1  2  3
# 3  0  2  4  4  0
# 4  1  1  0  4  0
# 5  3  3  0  1  0
# 6  3  1  4  2  2
# 7  1  3  3  0  2
# 8  3  4  0  1  1
# 9  2  4  4  3  0

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  4  0  0  2  1
# 1           1  1  1  4  3  3
# 2           2  1  0  1  2  3
# 3           3  0  2  4  4  0
# 4           4  1  1  0  4  0
# 5           5  3  3  0  1  0
# 6           6  3  1  4  2  2
# 7           7  1  3  3  0  2
# 8           8  3  4  0  1  1
# 9           9  2  4  4  3  0
